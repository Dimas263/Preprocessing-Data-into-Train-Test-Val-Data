# %% [markdown]
# # <img src="https://img.icons8.com/color/48/undefined/1-circle--v1.png"/>**Folder**

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **menyambungkan files dataset di google drive storage**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # <img src="https://img.icons8.com/color/48/undefined/2-circle--v1.png"/>**Exploratory Data Analysis (EDA) and Visualization**

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **menyiapkan Libraries Python**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **menampilkan dataset join order**

# %%
df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/sales/join_order.xlsx")
df
# Out:
#              id  order_id  user_id  product_id  inventory_item_id    status  \
# 0      142678.0   98658.0  79128.0     28951.0           385231.0  Returned
# 1      152447.0  105326.0  84559.0     28951.0           411732.0  Returned
# 2       39237.0   27222.0  21978.0     28557.0           105905.0  Returned
# 3       43331.0   29987.0  24222.0     28679.0           116984.0  Returned
# 4      101499.0   70266.0  56436.0     15419.0           274105.0  Returned
# ...         ...       ...      ...         ...                ...       ...
# 17747   36550.0   25342.0  20487.0       184.0            98689.0  Returned
# 17748   83752.0   58020.0  46700.0       417.0           226288.0  Returned
# 17749   84922.0   58842.0  47374.0       184.0           229443.0  Returned
# 17750   98934.0   68545.0  55023.0       417.0           267194.0  Returned
# 17751  167813.0  115892.0  93110.0      6992.0           453234.0  Returned
#
# ...

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **menampilkan 5 data pertama dari dataset join order**

# %%
df.head()
# Out:
#          id  order_id  user_id  product_id  inventory_item_id    status  \
# 0  142678.0   98658.0  79128.0     28951.0           385231.0  Returned
# 1  152447.0  105326.0  84559.0     28951.0           411732.0  Returned
# 2   39237.0   27222.0  21978.0     28557.0           105905.0  Returned
# 3   43331.0   29987.0  24222.0     28679.0           116984.0  Returned
# 4  101499.0   70266.0  56436.0     15419.0           274105.0  Returned
#
#   created_at shipped_at delivered_at returned_at  sale_price gender  \
# 0 2021-11-02 2021-11-02   2021-11-07  2021-11-08        30.0      M
# 1 2021-10-12 2021-10-13   2021-10-14  2021-10-16        30.0      M
# 2 2021-09-29 2021-10-01   2021-10-03  2021-10-05       325.0      M
# 3 2021-01-24 2021-01-27   2021-01-28  2021-01-29        35.0      M
# 4 2022-05-11 2022-05-13   2022-05-15  2022-05-15        35.0      F
#
#    num_of_item
# 0          2.0
# 1          3.0
# 2          1.0
# 3          1.0
# 4          1.0

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **menampilkan 5 data terakhir dari dataset join order**

# %%
df.tail()
# Out:
#              id  order_id  user_id  product_id  inventory_item_id    status  \
# 17747   36550.0   25342.0  20487.0       184.0            98689.0  Returned
# 17748   83752.0   58020.0  46700.0       417.0           226288.0  Returned
# 17749   84922.0   58842.0  47374.0       184.0           229443.0  Returned
# 17750   98934.0   68545.0  55023.0       417.0           267194.0  Returned
# 17751  167813.0  115892.0  93110.0      6992.0           453234.0  Returned
#
#       created_at shipped_at delivered_at returned_at    sale_price gender  \
# 17747 2022-05-30 2022-05-30   2022-06-02  2022-06-03  8.820000e+15      F
# 17748 2021-07-30 2021-07-31   2021-08-01  2021-08-03  8.820000e+15      F
# 17749 2022-03-23 2022-03-23   2022-03-28  2022-03-28  8.820000e+15      F
# 17750 2020-12-29 2020-12-31   2021-01-02  2021-01-05  8.820000e+15      F
# 17751 2021-05-12 2021-05-12   2021-05-14  2021-05-17  8.820000e+15      F
#
#        num_of_item
# 17747          4.0
# 17748          4.0
# ...

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **menghitung jumlah baris dan kolom dari dataset**

# %%
df.shape
# Out:
# (17752, 13)

# %% [markdown]
# ## ***pada dataset ini mempunyai 17752 baris and 13 kolom.***

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **menampilkan nama kolom dengan jumlah data masing-masing kolom dan tipe data yang digunakan, serta menghitung ukuran file dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17752 entries, 0 to 17751
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 17752 non-null  float64
#  1   order_id           17752 non-null  float64
#  2   user_id            17752 non-null  float64
#  3   product_id         17752 non-null  float64
#  4   inventory_item_id  17752 non-null  float64
#  5   status             17752 non-null  object
#  6   created_at         17752 non-null  datetime64[ns]
#  7   shipped_at         17752 non-null  datetime64[ns]
#  8   delivered_at       17752 non-null  datetime64[ns]
#  9   returned_at        17752 non-null  datetime64[ns]
#  10  sale_price         17752 non-null  float64
#  11  gender             17752 non-null  object
#  12  num_of_item        17752 non-null  float64
# dtypes: datetime64[ns](4), float64(7), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **menampilkan nama kolom dan tipe data yang digunakan**

# %%
df.dtypes
# Out:
# id                          float64
# order_id                    float64
# user_id                     float64
# product_id                  float64
# inventory_item_id           float64
# status                       object
# created_at           datetime64[ns]
# shipped_at           datetime64[ns]
# delivered_at         datetime64[ns]
# returned_at          datetime64[ns]
# sale_price                  float64
# gender                       object
# num_of_item                 float64
# dtype: object

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **Menghitung jumlah Non-Missing Values dari setiap variable**

# %%
df.count()
# Out:
# id                   17752
# order_id             17752
# user_id              17752
# product_id           17752
# inventory_item_id    17752
# status               17752
# created_at           17752
# shipped_at           17752
# delivered_at         17752
# returned_at          17752
# sale_price           17752
# gender               17752
# num_of_item          17752
# dtype: int64

# %% [markdown]
# ## **total 17752 data yang tidak memiliki missing value**

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **mendeskripsikan dan menghitung nilai rata-rata setiap kolom dataset**

# %%
df.describe()
# Out:
#                   id       order_id       user_id    product_id  \
# count   17752.000000   17752.000000  17752.000000  17752.000000
# mean    90644.236537   62675.719074  50385.719468  15151.775687
# std     52510.971853   36269.656689  29062.411279   8435.641404
# min        17.000000       9.000000      6.000000      1.000000
# 25%     44260.000000   30647.500000  24749.750000   7755.750000
# 50%     91386.500000   63307.000000  50879.000000  15801.500000
# 75%    136279.750000   94271.750000  75665.750000  22428.500000
# max    180504.000000  124508.000000  99997.000000  29120.000000
#
#        inventory_item_id    sale_price   num_of_item
# count       17752.000000  1.775200e+04  17752.000000
# mean       244774.486480  8.137358e+15      1.902321
# std        141798.943611  1.296444e+16      1.049199
# min            45.000000  3.000000e+01      1.000000
# 25%        119485.750000  5.500000e+02      1.000000
# 50%        246820.500000  4.000000e+14      2.000000
# ...

# %% [markdown]
# # <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **Data Cleansing**

# %% [markdown]
# ## **mengecek apakah masih ada missing value dari setiap variabel**

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **hapus data missng value jika masih ada**

# %%
df.dropna(how='any', inplace=True)

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **mengecek data dan menampilkan data jika bernilai 0, maka tidak ada missing value, jika bernilai lebih dari 0, maka itu jumlah missing value**

# %%
df.isnull().sum()
# Out:
# id                   0
# order_id             0
# user_id              0
# product_id           0
# inventory_item_id    0
# status               0
# created_at           0
# shipped_at           0
# delivered_at         0
# returned_at          0
# sale_price           0
# gender               0
# num_of_item          0
# dtype: int64

# %% [markdown]
# # <img src="https://img.icons8.com/color/48/undefined/3-circle--v1.png"/>**Data Visualizations**

# %%
import seaborn as sns

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **visualisasi pada created_at**

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

plt.figure(figsize=(18,5))
sns.countplot(x = df['created_at'], palette="rocket", linewidth = 1)
plt.show()

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **visualisasi pada shipped_at**

# %%
df['shipped_at'] = pd.to_datetime(df['shipped_at'])

plt.figure(figsize=(18,5))
sns.countplot(x = df['shipped_at'], palette="mako", linewidth = 1)
plt.show()

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **visualisasi pada delivered_at**

# %%
df['delivered_at'] = pd.to_datetime(df['delivered_at'])

plt.figure(figsize=(18,5))
sns.countplot(x = df['delivered_at'], palette="flare", linewidth = 1)
plt.show()

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **visualisasi pada returned_at**

# %%
df['returned_at'] = pd.to_datetime(df['returned_at'])

plt.figure(figsize=(18,5))
sns.countplot(x = df['returned_at'], palette="Blues", linewidth = 1)
plt.show()

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **visualisasi pada gender dan number item**

# %%
x,y = 'gender', 'num_of_item'

df1 = df.groupby(x)[y].value_counts(normalize=True)
df1 = df1.mul(100)
df1 = df1.rename('percent').reset_index()

g = sns.catplot(x=x,y='percent',hue=y,kind='bar',data=df1)
g.ax.set_ylim(0,100)

for p in g.ax.patches:
    txt = str(p.get_height().round(2)) + '%'
    txt_x = p.get_x() 
    txt_y = p.get_height()
    g.ax.text(txt_x,txt_y,txt)

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **visualisasi pada gender dan status returned**

# %%
x,y = 'status', 'gender'

df1 = df.groupby(x)[y].value_counts(normalize=True)
df1 = df1.mul(100)
df1 = df1.rename('percent').reset_index()

g = sns.catplot(x=x,y='percent',hue=y,kind='bar',data=df1)
g.ax.set_ylim(0,100)

for p in g.ax.patches:
    txt = str(p.get_height().round(2)) + '%'
    txt_x = p.get_x() 
    txt_y = p.get_height()
    g.ax.text(txt_x,txt_y,txt)

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **visualisasi presentase number item**

# %%
plt.pie(df['num_of_item'].value_counts(), labels = df['num_of_item'].unique(),autopct='%1.2f%%')
print("Number Of Items")
plt.show()
# Out:
# Number Of Items

# %% [markdown]
# # <img src="https://img.icons8.com/color/48/undefined/4-circle--v1.png"/>**Data Spliting**

# %%
import re
import json
import pandas as pd
from pprint import pprint

df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/sales/join_order.xlsx')

texts = []
for id, order_id, user_id, product_id, inventory_item_id, status, created_at, shipped_at, delivered_at, returned_at, sale_price, gender, num_of_item in zip(
    df['id'].tolist(), df['order_id'].tolist(), df['user_id'].tolist(), df['product_id'].tolist(), df['inventory_item_id'].tolist(), 
    df['status'].tolist(), df['created_at'].tolist(), df['shipped_at'].tolist(), df['delivered_at'].tolist(), df['returned_at'].tolist(), 
    df['sale_price'].tolist(), df['gender'].tolist(), df['num_of_item'].tolist()
    ):
    created_at = pd.to_datetime(created_at).date()
    shipped_at = pd.to_datetime(shipped_at).date()
    delivered_at = pd.to_datetime(delivered_at).date()
    returned_at = pd.to_datetime(returned_at).date()
    texts.append([id, order_id, user_id, product_id, inventory_item_id, status, created_at, shipped_at, delivered_at, returned_at, sale_price, gender, num_of_item])

df = pd.DataFrame(texts, columns=['id', 'order_id', 'user_id', 'product_id', 'inventory_item_id', 'status', 'created_at', 'shipped_at', 'delivered_at', 'returned_at', 'sale_price', 'gender', 'num_of_item'])

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **Train Data**

# %%
! pip install xlsxwriter

import xlsxwriter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
train_df = df.sample(frac=0.8, random_state=1)

writer = pd.ExcelWriter('/content/drive/MyDrive/Colab Notebooks/sales/train.xlsx', engine='xlsxwriter')
train_df.to_excel(writer, sheet_name='Sheet1')
writer.save()

# %%
train = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/sales/train.xlsx")
train
# Out:
#        Unnamed: 0      id  order_id  user_id  product_id  inventory_item_id  \
# 0           12492   31660     21949    17788       27121              85413
# 1           17335   41973     29068    23456       26589             113276
# 2            5358   65426     45219    36473       22173             176718
# 3           16007   31184     21609    17522        8501              84139
# 4           17319  157163    108588    87215       15906             424487
# ...           ...     ...       ...      ...         ...                ...
# 14197        9096   93544     64807    52054       28191             252675
# 14198       15486  148953    102917    82627        6298             402267
# 14199        1670  132080     91333    73259         536             356584
# 14200        9917   52956     36603    29562       20049             143006
# 14201       16382   46433     32125    25964       19880             125414
#
# ...

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **Test Data**

# %%
test_df = df.drop(train_df.index)

writer = pd.ExcelWriter('/content/drive/MyDrive/Colab Notebooks/sales/test.xlsx', engine='xlsxwriter')
test_df.to_excel(writer, sheet_name='Sheet1')
writer.save()

# %%
test = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/sales/test.xlsx")
test
# Out:
#       Unnamed: 0      id  order_id  user_id  product_id  inventory_item_id  \
# 0              9    4805      3295     2662       28370              13038
# 1             14  177017    122150    98116        9002             477975
# 2             15      74        51       33        9380                198
# 3             18   67362     46557    37544       13840             181949
# 4             20   89666     62129    49973       15667             242242
# ...          ...     ...       ...      ...         ...                ...
# 3545       17723  145163    100321    80484       23505             391953
# 3546       17728   51234     35442    28673         201             138334
# 3547       17734   46432     32125    25964       28895             125412
# 3548       17739  169319    116946    93981        3429             457289
# 3549       17750   98934     68545    55023         417             267194
#
#         status created_at shipped_at delivered_at returned_at  \
# ...

# %% [markdown]
# ## <img src="https://img.icons8.com/parakeet/24/undefined/experimental-arrow-parakeet.png"/> **Validation Data**

# %%
val_df = test_df.sample(frac=0.4, random_state=1024)

writer = pd.ExcelWriter('/content/drive/MyDrive/Colab Notebooks/sales/val.xlsx', engine='xlsxwriter')
val_df.to_excel(writer, sheet_name='Sheet1')
writer.save()

# %%
val = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/sales/val.xlsx")
val
# Out:
#       Unnamed: 0      id  order_id  user_id  product_id  inventory_item_id  \
# 0          15383   16693     11506     9402       19675              45108
# 1          11970    2115      1464     1158        2020               5747
# 2          14384    6963      4782     3892        3028              18872
# 3          10856   95499     66151    53127       13821             257950
# 4           7695  137445     95072    76289       27161             371083
# ...          ...     ...       ...      ...         ...                ...
# 1415        9887   95238     65964    52980       16175             257249
# 1416        5909   96098     66561    53446       23188             259545
# 1417       10777   41410     28685    23155       11038             111763
# 1418       11401  170597    117821    94709       16771             460706
# 1419       14359   59798     41355    33398        3847             161499
#
#         status created_at shipped_at delivered_at returned_at  \
# ...

# %% [markdown]
# # <img src="https://img.icons8.com/color/48/undefined/5-circle--v1.png"/>**summary**

# %% [markdown]
# # Train Data `14202 rows × 14 columns`
# # Test Data `3550 rows × 14 columns`
# # Validation Data `1420 rows × 14 columns`
